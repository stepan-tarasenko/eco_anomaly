# %%
import pandas as pd
import geopy.distance
import matplotlib as plt
import numpy as np

# %%
co2 = pd.read_excel (r'co2.xlsx')
no2 = pd.read_excel (r'no2.xlsx')
no = pd.read_excel (r'no.xlsx')
cam_ids = pd.read_excel (r'cam_ids.xlsx')
pm_2_5 = pd.read_excel (r'pm2.5.xlsx')
pm_10 = pd.read_excel (r'pm10.xlsx')

# %%
print('Co2: ')
co2.head()
# Out:
# Co2:
#          DATE'  ID_CAMS'   00:00:00   01:00:00   02:00:00   03:00:00  \
# 0  2019-01-01'      6192  233.81799  229.32230  227.42313  219.82350
# 1  2019-01-01'      6193  220.94206  224.53630  230.81827  237.80513
# 2  2019-01-01'      6194  205.43085  217.55070  217.54306  219.14752
# 3  2019-01-01'      6377  213.45760  228.90984  223.07506  221.68069
# 4  2019-01-01'      6378  213.61369  218.78398  219.40958  221.92990
#
#     04:00:00   05:00:00   06:00:00   07:00:00  ...   14:00:00   15:00:00  \
# 0  243.31866  267.41788  299.35608  324.42630  ...  244.65617  242.93916
# 1  247.53349  273.50150  319.83313  370.46298  ...  277.30066  275.71735
# 2  232.19714  257.57010  289.49374  328.43704  ...  280.94559  266.11740
# 3  245.80739  268.12796  325.81613  342.96521  ...  249.27005  252.03412
# 4  241.78207  271.63882  321.34949  351.38123  ...  280.85202  283.58676
#
#     16:00:00   17:00:00   18:00:00   19:00:00   20:00:00   21:00:00  \
# ...

# %%
print('No2: ')
no2.head()
# Out:
# No2:
#         'DATE'  'ID_CAMS'   00:00:00   01:00:00   02:00:00   03:00:00  \
# 0  2019-01-01'       6192  13.980017  10.318384   7.463131   6.987891
# 1  2019-01-01'       6193  13.698124  14.990359  15.093813  15.194304
# 2  2019-01-01'       6194  10.204271  11.970837  12.701842  12.915111
# 3  2019-01-01'       6377  10.904277   9.417352   8.648395   8.724756
# 4  2019-01-01'       6378  12.990359  14.006044  13.659362  13.533595
#
#     04:00:00   05:00:00   06:00:00   07:00:00  ...   14:00:00   15:00:00  \
# 0   8.111872  12.301242  16.371550  12.661986  ...   7.444738   8.623218
# 1  16.386057  19.672064  25.677002  24.682671  ...  17.560749  20.189880
# 2  14.074121  16.698015  21.710667  23.339476  ...  17.366962  19.230307
# 3  10.171366  15.123204  18.528671  15.146491  ...  11.108290  13.140848
# 4  15.011981  21.831203  28.517582  22.400160  ...  17.769037  20.337204
#
#     16:00:00   17:00:00   18:00:00   19:00:00   20:00:00   21:00:00  22:00:00  \
# ...

# %%
print('No: ')
no.head()
# Out:
# No:
#         'DATE'  'ID_CAMS'  00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  \
# 0  2019-01-01'       6192  0.169393  0.155381  0.146748  0.149829  0.198874
# 1  2019-01-01'       6193  0.248932  0.205866  0.230159  0.284984  0.365276
# 2  2019-01-01'       6194  0.141313  0.156945  0.158749  0.163539  0.304368
# 3  2019-01-01'       6377  0.451202  0.400931  0.349516  0.382684  0.590802
# 4  2019-01-01'       6378  0.582112  0.612332  0.600167  0.693248  0.977714
#
#    05:00:00  06:00:00  07:00:00  ...  14:00:00  15:00:00  16:00:00  17:00:00  \
# 0  0.518476  1.212285  3.476423  ...  0.810246  0.566942  0.559481  0.467026
# 1  1.036199  2.194426  8.018688  ...  2.177323  1.344432  0.984528  0.769418
# 2  0.704105  1.648424  4.448644  ...  2.548525  0.899362  0.754710  0.547573
# 3  0.980904  2.493035  7.329028  ...  2.079126  1.951555  1.903786  1.225999
# 4  2.312426  3.919862  6.294577  ...  4.311005  3.566939  3.231186  2.102467
#
# ...

# %%
print('Cam ids: ')
cam_ids.head()
# Out:
# Cam ids:
#    ID посту          x          y  ID CAMS
# 0        28  50.444000  30.540000     6563
# 1        30  50.434000  30.432000     6562
# 2        43  50.411719  30.618949     6564
# 3        47  50.472938  30.508250     6378
# 4       108  50.362592  30.442744     6747

# %%
print('pm 2.5: ')
pm_2_5.head()
# Out:
# pm 2.5:
#          DATE'  ID_CAMS'   00:00:00   01:00:00   02:00:00   03:00:00  \
# 0  2019-01-01'      6192  11.714356  11.732362  11.612226  10.763933
# 1  2019-01-01'      6193  13.346999  13.686141  13.548043  12.896982
# 2  2019-01-01'      6194  12.358634  12.547952  13.980294  13.308074
# 3  2019-01-01'      6377  11.799749  12.341723  12.012091  11.372783
# 4  2019-01-01'      6378  12.193746  13.320908  13.704476  12.667178
#
#     04:00:00   05:00:00   06:00:00   07:00:00  ...  14:00:00  15:00:00  \
# 0  10.951051  11.699828  13.004950  12.379587  ...  7.667426  7.596575
# 1  12.974633  13.672379  15.475791  15.566513  ...  8.348609  8.411852
# 2  13.012832  13.836046  14.479198  15.597777  ...  8.676738  8.103078
# 3  11.227167  12.694758  13.512632  13.325547  ...  7.701589  7.642505
# 4  13.811369  14.089795  15.557291  15.367334  ...  8.445015  8.642921
#
#    16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  22:00:00  \
# ...

# %%
print('pm 10: ')
pm_10.head()
# Out:
# pm 10:
#          DATE'  ID_CAMS'   00:00:00   01:00:00   02:00:00   03:00:00  \
# 0  2019-01-01'      6192  11.853447  11.947265  11.991467  11.632629
# 1  2019-01-01'      6193  14.598501  13.860188  14.288509  13.902984
# 2  2019-01-01'      6194  13.306933  14.110753  14.872319  14.277696
# 3  2019-01-01'      6377  11.945192  12.479603  12.654488  11.977129
# 4  2019-01-01'      6378  13.583931  14.461619  14.784383  13.227783
#
#     04:00:00   05:00:00   06:00:00   07:00:00  ...  14:00:00  15:00:00  \
# 0  11.651216  12.298962  13.926763  13.292529  ...  7.942982  7.914372
# 1  13.676447  15.493590  16.340363  16.226303  ...  8.816551  9.553566
# 2  14.021089  14.304113  16.197060  16.221329  ...  9.072688  8.936247
# 3  12.028798  13.301566  13.812934  13.612131  ...  8.013809  8.109459
# 4  14.323950  14.991350  16.208088  16.765520  ...  8.571898  8.774356
#
#    16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  22:00:00  \
# ...

# %%
def calculate_distance_between_two_cameras_in_km(x1, y1, x2, y2):
    coords_1 = (x1, y1)
    coords_2 = (x2, y2)
    return geopy.distance.vincenty(coords_1, coords_2).km
