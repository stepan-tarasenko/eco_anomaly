# %%
from matplotlib import pyplot as plt

import pandas as pd
import geopy.distance
import numpy as np
import datetime

# %% [markdown]
# ## Read Data

# %%
co2 = pd.read_excel(r'co2.xlsx')
no2 = pd.read_excel(r'no2.xlsx')
no = pd.read_excel(r'no.xlsx')
cam_ids = pd.read_excel(r'cam_ids.xlsx')
pm_2_5 = pd.read_excel(r'pm2.5.xlsx')
pm_10 = pd.read_excel(r'pm10.xlsx')

# %% [markdown]
# ## Data cleanup

# %%
# Rename columns
co2 = co2.rename(columns={'DATE\'': 'DATE', 'ID_CAMS\'' : 'ID_CAMS'})
no2 = no2.rename(columns={'\'DATE\'': 'DATE', '\'ID_CAMS\'' : 'ID_CAMS'})
no = no.rename(columns={'\'DATE\'': 'DATE', '\'ID_CAMS\'' : 'ID_CAMS'})
cam_ids = cam_ids.rename(columns={'ID посту': 'id', 'ID CAMS' : 'ID_CAMS'})
pm_2_5 = pm_2_5.rename(columns={'DATE\'': 'DATE', 'ID_CAMS\'' : 'ID_CAMS'})
pm_10 = pm_10.rename(columns={'DATE\'': 'DATE', 'ID_CAMS\'' : 'ID_CAMS'})

# Remove ' char from DATE column
co2['DATE'] = co2['DATE'].replace({'\'':''}, regex=True)
no2['DATE'] = no2['DATE'].replace({'\'':''}, regex=True)
no['DATE'] = no['DATE'].replace({'\'':''}, regex=True)
pm_2_5['DATE'] = pm_2_5['DATE'].replace({'\'':''}, regex=True)
pm_10['DATE'] = pm_10['DATE'].replace({'\'':''}, regex=True)

# %% [markdown]
# ## Print prepared data

# %%
print('Co2: ')
co2.head()
# Out:
# Co2:
#          DATE  ID_CAMS          1          2          3          4          5  \
# 0  2019-01-01     6192  233.81799  229.32230  227.42313  219.82350  243.31866
# 1  2019-01-01     6193  220.94206  224.53630  230.81827  237.80513  247.53349
# 2  2019-01-01     6194  205.43085  217.55070  217.54306  219.14752  232.19714
# 3  2019-01-01     6377  213.45760  228.90984  223.07506  221.68069  245.80739
# 4  2019-01-01     6378  213.61369  218.78398  219.40958  221.92990  241.78207
#
#            6          7          8  ...         15         16         17  \
# 0  267.41788  299.35608  324.42630  ...  244.65617  242.93916  238.78931
# 1  273.50150  319.83313  370.46298  ...  277.30066  275.71735  272.85922
# 2  257.57010  289.49374  328.43704  ...  280.94559  266.11740  268.60004
# 3  268.12796  325.81613  342.96521  ...  249.27005  252.03412  248.00113
# 4  271.63882  321.34949  351.38123  ...  280.85202  283.58676  277.15088
#
# ...

# %%
print('No2: ')
no2.head()
# Out:
# No2:
#          DATE  ID_CAMS          1          2          3          4          5  \
# 0  2019-01-01     6192  13.980017  10.318384   7.463131   6.987891   8.111872
# 1  2019-01-01     6193  13.698124  14.990359  15.093813  15.194304  16.386057
# 2  2019-01-01     6194  10.204271  11.970837  12.701842  12.915111  14.074121
# 3  2019-01-01     6377  10.904277   9.417352   8.648395   8.724756  10.171366
# 4  2019-01-01     6378  12.990359  14.006044  13.659362  13.533595  15.011981
#
#            6          7          8  ...         15         16         17  \
# 0  12.301242  16.371550  12.661986  ...   7.444738   8.623218   9.002022
# 1  15.493590  16.340363  16.226303  ...  8.816551  9.553566  9.598605
# 2  14.304113  16.197060  16.221329  ...  9.072688  8.936247  8.889370
# 3  13.301566  13.812934  13.612131  ...  8.013809  8.109459  8.899261
# 4  14.991350  16.208088  16.765520  ...  8.571898  8.774356  8.857082
#
# ...

# %% [markdown]
# ## Calculate distance between two cameras by their ids

# %%
def calculate_distance_between_two_cameras_in_km(cam_id_1, cam_id_2):
    cam_1 = cam_ids[cam_ids['ID_CAMS'] == cam_id_1]
    cam_2 = cam_ids[cam_ids['ID_CAMS'] == cam_id_2]
    coords_1 = (float(cam_1.iloc[0]['x']), float(cam_1.iloc[0]['y']))
    coords_2 = (float(cam_2.iloc[0]['x']), float(cam_2.iloc[0]['y']))
    return geopy.distance.geodesic(coords_1, coords_2).km

# %% [markdown]
# ## Function to find anomalies in dataframe

# %%
def iteration_through_dataframe(dataframe):
    start_date = datetime.datetime.strptime(dataframe['DATE'][dataframe.index[0]], "%Y-%m-%d").date()
    end_date = datetime.datetime.strptime(dataframe['DATE'][dataframe.index[-1]], "%Y-%m-%d").date()
    current_date = start_date
    while current_date != end_date:
        
        current_date = current_date + datetime.timedelta(days=1)
        current_date_dataframe = dataframe[dataframe['DATE'] == str(current_date)]
        
        for index_e, row_e in current_date_dataframe.iterrows():
            
            nearest_cameras_ids_for_current = []
            mean_for_current_cam = 0
            std_for_current_cam = 0
            
            for index_i, row_i in current_date_dataframe.iterrows():
                if calculate_distance_between_two_cameras_in_km(row_e['ID_CAMS'], row_i['ID_CAMS']) < 15:
                    nearest_cameras_ids_for_current.append(row_i['ID_CAMS'])

            for i in range(1,23):
                val_list = []
                for cam_id in nearest_cameras_ids_for_current:
                    val_list.append(current_date_dataframe[current_date_dataframe['ID_CAMS'] == cam_id].iloc[0][i])

                mean_for_current_cam = np.mean(np.array(val_list), dtype=np.float64)
                std_for_current_cam = np.std(np.array(val_list), dtype=np.float64)

                if row_e[i] >= mean_for_current_cam + 2*std_for_current_cam:
                    print('Anomaly data camera_id:%s, time:%s ' % (str(row_e['ID_CAMS']), str(i)))
                    df = pd.DataFrame({
                      'data': val_list,
                      'mean': mean_for_current_cam})

                    df.plot()
                    plt.show()

# %%
iteration_through_dataframe(co2)
# Out:
# Anomaly data camera_id:6193, time:15
# Anomaly data camera_id:6193, time:16
# Anomaly data camera_id:6193, time:17
# Anomaly data camera_id:6193, time:18
# Anomaly data camera_id:6747, time:7
# Anomaly data camera_id:6747, time:16
# Anomaly data camera_id:6194, time:3
# Anomaly data camera_id:6194, time:15
# Anomaly data camera_id:6194, time:10
# Anomaly data camera_id:6194, time:11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-205-6bf3e4a48f38> in <module>
# ----> 1 iteration_through_dataframe(co2)
#
# <ipython-input-204-ad1f3f73a352> in iteration_through_dataframe(dataframe)
#      16                 val_list = []
#      17                 for cam_id in nearest_cameras_ids_for_current:
# ---> 18                     val_list.append(current_date_dataframe[current_date_dataframe['ID_CAMS'] == cam_id].iloc[0][i])
#      19
# ...

# %%
iteration_through_dataframe(no)
# Out:
# Anomaly data camera_id:6747, time:1
# Anomaly data camera_id:6193, time:21
# Anomaly data camera_id:6193, time:22
# Anomaly data camera_id:6747, time:12
# Anomaly data camera_id:6747, time:13
# Anomaly data camera_id:6747, time:8
# Anomaly data camera_id:6193, time:8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-51a6d2157dc7> in <module>
# ----> 1 iteration_through_dataframe(no)
#
# <ipython-input-204-ad1f3f73a352> in iteration_through_dataframe(dataframe)
#      16                 val_list = []
#      17                 for cam_id in nearest_cameras_ids_for_current:
# ---> 18                     val_list.append(current_date_dataframe[current_date_dataframe['ID_CAMS'] == cam_id].iloc[0][i])
#      19
#      20                 mean_for_current_cam = np.mean(np.array(val_list), dtype=np.float64)
#
# ...

# %%
iteration_through_dataframe(no2)
# Out:
# Anomaly data camera_id:6747, time:18
# Anomaly data camera_id:6747, time:19
# Anomaly data camera_id:6747, time:20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-36d583ffef44> in <module>
# ----> 1 iteration_through_dataframe(no2)
#
# <ipython-input-204-ad1f3f73a352> in iteration_through_dataframe(dataframe)
#      11             std_for_current_cam = 0
#      12             for index_i, row_i in current_date_dataframe.iterrows():
# ---> 13                 if calculate_distance_between_two_cameras_in_km(row_e['ID_CAMS'], row_i['ID_CAMS']) < 15:
#      14                     nearest_cameras_ids_for_current.append(row_i['ID_CAMS'])
#      15             for i in range(1,23):
#
# <ipython-input-184-c9e2dd87bd3c> in calculate_distance_between_two_cameras_in_km(cam_id_1, cam_id_2)
#       4     coords_1 = (float(cam_1.iloc[0]['x']), float(cam_1.iloc[0]['y']))
# ...

# %%
iteration_through_dataframe(pm_2_5)
# Out:
# Anomaly data camera_id:6193, time:14
# Anomaly data camera_id:6747, time:11
# Anomaly data camera_id:6194, time:3
# Anomaly data camera_id:6194, time:6
# Anomaly data camera_id:6747, time:17
# Anomaly data camera_id:6747, time:3
# Anomaly data camera_id:6193, time:6
# Anomaly data camera_id:6193, time:7
# Anomaly data camera_id:6193, time:11
# Anomaly data camera_id:6747, time:2
# Anomaly data camera_id:6747, time:12
# Anomaly data camera_id:6193, time:8
# Anomaly data camera_id:6194, time:22
# Anomaly data camera_id:6194, time:13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-208-0220fcf02cd5> in <module>
# ----> 1 iteration_through_dataframe(pm_2_5)
#
# <ipython-input-204-ad1f3f73a352> in iteration_through_dataframe(dataframe)
#      16                 val_list = []
#      17                 for cam_id in nearest_cameras_ids_for_current:
# ...

# %%
iteration_through_dataframe(pm_10)
# Out:
# Anomaly data camera_id:6193, time:13
# Anomaly data camera_id:6748, time:15
# Anomaly data camera_id:6747, time:17
# Anomaly data camera_id:6194, time:3
# Anomaly data camera_id:6194, time:4
# Anomaly data camera_id:6194, time:6
# Anomaly data camera_id:6194, time:14
# Anomaly data camera_id:6193, time:6
# Anomaly data camera_id:6193, time:11
# Anomaly data camera_id:6747, time:2
# Anomaly data camera_id:6747, time:3
# Anomaly data camera_id:6747, time:12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-209-dab8172ea5c2> in <module>
# ----> 1 iteration_through_dataframe(pm_10)
#
# <ipython-input-204-ad1f3f73a352> in iteration_through_dataframe(dataframe)
#      16                 val_list = []
#      17                 for cam_id in nearest_cameras_ids_for_current:
# ...
